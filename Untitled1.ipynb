# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

np.random.seed(42)
mehdi = np.random.rand(5000, 5000)

pca = PCA(n_components=2)
mehdi9810 = pca.fit_transform(mehdi)

plt.figure(figsize=(10, 5))


plt.subplot(1, 2, 1)
plt.scatter(mehdi[:, 0], mehdi[:, 1], alpha=0.5)
plt.title('mehdi 1')


plt.subplot(1, 2, 2)
plt.scatter(mehdi_avas[:, 0], mehdi_avas[:, 1], alpha=0.5)
plt.title('mehdi 2')

print("Original Data:")
print(mehdi[:5])
print("\n mehdi 9810 bad az PCA:")
print(mehdi_avas[:5])

plt.tight_layout()
plt.show()
# Out:
# Original Data:
# [[0.37454012 0.95071431 0.73199394 ... 0.32784284 0.81574538 0.59731238]
#  [0.39363552 0.47343566 0.85454739 ... 0.94670792 0.39748799 0.2171404 ]
#  [0.37364082 0.3329121  0.17615391 ... 0.05123954 0.68296159 0.25107902]
#  [0.49967024 0.74674677 0.56266678 ... 0.30369847 0.44332001 0.17226481]
#  [0.72999831 0.184512   0.34663969 ... 0.92327409 0.63728565 0.95183855]]
#
#  mehdi 9810 bad az PCA:
# [[ 0.35285123 -0.37510159]
#  [-0.46856918  0.70581357]
#  [-0.72231034 -0.56641728]
#  [-0.64702556 -0.49126265]
#  [-0.35943851 -0.63004057]]
